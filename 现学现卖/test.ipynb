# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']  # 黑体
plt.rcParams['axes.unicode_minus'] = False  # 解决无法显示符号的问题
palette = 'deep'
sns.set(font='SimHei', font_scale=1.2, palette=palette)  # 解决Seaborn中文显示问题

# %%
import librosa

# 加载音频文件
audio_file = 'RS02062Dduld1JSgLy.wav'
y, sr = librosa.load(audio_file)
print(sr)
y
# Out:
# 22050
# array([-2.0093281e-05, -1.4367433e-06,  3.4876386e-05, ...,
#        -9.0462156e-05, -1.0084885e-04, -3.3156801e-05], dtype=float32)

# %%
# 计算MFCC特征
mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)

mfccs
# Out:
# array([[-5.1925726e+02, -2.1366847e+02, -3.1739466e+01, ...,
#         -2.5909128e+02, -2.9754520e+02, -3.5921127e+02],
#        [ 0.0000000e+00,  7.3636856e+01,  5.7651150e+01, ...,
#          4.6206890e+01,  4.6335148e+01,  5.2259598e+01],
#        [ 0.0000000e+00, -1.5851105e+01, -1.5054739e+01, ...,
#         -1.5216923e+00,  6.8300009e-01,  4.6062822e+00],
#        ...,
#        [ 0.0000000e+00,  4.6926861e+00,  8.6567078e+00, ...,
#         -4.7935810e+00, -3.2778535e+00, -8.1207085e-01],
#        [ 0.0000000e+00,  6.5378914e+00,  9.6854763e+00, ...,
#          2.1617365e-01, -3.4549856e+00, -3.5479889e+00],
#        [ 0.0000000e+00,  3.1983464e+00,  4.4353161e+00, ...,
#         -7.4290104e+00, -9.2990837e+00, -9.1655502e+00]], dtype=float32)

# %%
from sklearn import preprocessing
# 打印MFCC特征的形状
print("MFCC shape:", mfccs.shape)

# 可视化MFCC特征
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 4))
librosa.display.specshow(mfccs, x_axis='time')
plt.colorbar()
plt.title('MFCC')
plt.tight_layout()
plt.show()
# Out:
# MFCC shape: (13, 2584)

# %%
from util import convertEMF

# %%
import numpy as np
import matplotlib.pyplot as plt
tt = np.linspace(0, 2*3.14159)
plt.plot(tt, np.sin(tt))
convertEMF.exportEmf('.', 'FileName')

# %%
convertEMF.convertEmf(r'E:\Programing\PycharmProjects\2023.tfmcm.com\现学现卖\尺度能量图.svg')
# Out:
# 'E:\\Programing\\PycharmProjects\\2023.tfmcm.com\\图片处理/Untitled.emf'
